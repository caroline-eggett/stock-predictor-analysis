# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
# %matplotlib inline

# %%
df_amazon = pd.read_csv('data/Stocks/amzn.us.txt', sep=',')
print('Dimensions: ' + str(df_amazon.shape))
df_amazon.head()
# Out:
# Dimensions: (5153, 7)
#          Date  Open  High   Low  Close    Volume  OpenInt
# 0  1997-05-16  1.97  1.98  1.71   1.73  14700000        0
# 1  1997-05-19  1.76  1.77  1.62   1.71   6106800        0
# 2  1997-05-20  1.73  1.75  1.64   1.64   5467200        0
# 3  1997-05-21  1.64  1.65  1.38   1.43  18853200        0
# 4  1997-05-22  1.44  1.45  1.31   1.40  11776800        0

# %%
df_amazon_subset = df_amazon[(df_amazon['Date'] >= '2017-10-01') & (df_amazon['Date'] <= '2017-11-31')]
df_amazon_subset.head()
print("Shape for 2017: " + str(df_amazon_subset.shape))
# Out:
# Shape for 2017: (30, 7)

# %%
figure(figsize=(21, 14), dpi=80)
plt.plot(df_amazon_subset['Date'], df_amazon_subset['Open'])
plt.xticks(np.arange(0, 30, 3))
plt.show()
